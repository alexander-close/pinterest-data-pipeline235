# %% [markdown]
# The following cell runs dependent notebooks which:
# - mount the S3 bucket
# - store utility functions
# - store SQL-type queries
#
# respectively.

# %%
# %run ./mount_s3
# %run ./functions
# %run ./queries
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(dbutils.fs.ls("/mnt/126ca3664fbb-mount/topics/126ca3664fbb.geo/"))
# to unmount
# dbutils.fs.unmount("/mnt/<mount name>")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/126ca3664fbb-mount/topics/126ca3664fbb.geo/partition=0/</td><td>partition=0/</td><td>0</td><td>1723645017518</td></tr></tbody></table></div>

# %%
# %sql
--Disables format checks during the reading of Delta tables
SET spark.databricks.delta.formatCheck.enabled=false
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th></tr></thead><tbody><tr><td>spark.databricks.delta.formatCheck.enabled</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# Reading in S3 JSON data as DataFrames

# %%
df_pin, df_geo, df_pin = [read_from_s3(i) for i in ['pin', 'geo', 'user']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Applying the cleaning/transforming functions on tables and calling the new dataframes:

# %%
df_pin = clean_pin_table(df_pin)
df_pin
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[176]: DataFrame[ind: bigint, unique_id: string, title: string, description: string, follower_count: int, poster_name: string, tag_list: string, is_image_or_video: string, image_src: string, save_location: string, category: string, downloaded: bigint]</div>

# %%
df_geo = clean_geo_table(df_geo)
df_geo
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[177]: DataFrame[ind: bigint, country: string, coordinates: array&lt;double&gt;, timestamp: timestamp]</div>

# %%
df_user = clean_user_table(df_user)
df_user
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[178]: DataFrame[ind: bigint, user_name: string, age: bigint, date_joined: timestamp]</div>

# %%
# Dataframe columns for reference

print(df_pin.columns)
print('--------------------------------------------')
print(df_geo.columns)
print('--------------------------------------------')
print(df_user.columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;ind&#39;, &#39;unique_id&#39;, &#39;title&#39;, &#39;description&#39;, &#39;follower_count&#39;, &#39;poster_name&#39;, &#39;tag_list&#39;, &#39;is_image_or_video&#39;, &#39;image_src&#39;, &#39;save_location&#39;, &#39;category&#39;, &#39;downloaded&#39;]
# --------------------------------------------
# [&#39;ind&#39;, &#39;country&#39;, &#39;coordinates&#39;, &#39;timestamp&#39;]
# --------------------------------------------
# [&#39;ind&#39;, &#39;user_name&#39;, &#39;age&#39;, &#39;date_joined&#39;]
# </div>

# %%
fol_age_year.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+-----------+---------------------+
# age_group|year_joined|median_follower_count|
# +---------+-----------+---------------------+
#     18-24|       2015|               211000|
#     18-24|       2016|                46000|
#     18-24|       2017|                10000|
#     25-35|       2015|                51000|
#     25-35|       2016|                41000|
#     25-35|       2017|                 8000|
#     36-49|       2015|                13000|
#     36-49|       2016|                11000|
#     36-49|       2017|                 6000|
#       50+|       2015|                  196|
#       50+|       2016|                 1000|
#       50+|       2017|                 4000|
# +---------+-----------+---------------------+
#
# </div>

# %%
by_country.show()

# %%
by_year.show()

# %%
country_most_followers.show()

# %%
most_followers.show()

# %%
fol_age_group.show()

# %%
fol_by_year.show()
